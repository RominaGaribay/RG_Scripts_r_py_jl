# %%
import random as random
import math

# Crear un vector aleatorio entre 0 y 500, 
# luego aplicar esta condición a cada uno de los elementos.



for 
    x= random.randint(0, 500)
  





print(f)

# %% [markdown]
# 1- Elaborar una estructura If statement para la siguiente función.
#
# Crear un vector aleatorio entre 0 y 500,
# luego aplicar esta condición a cada uno de los elementos.

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
x1 = np.random.rand(500)*500

# %%
L = []

for x in x1:
    if x >= 0 or x <= 100:
        f = math.sqrt(x)
    elif x <= 300 or x >100:
        f = x-5
    else:
        f=50
    L.append(f)
    
L
# Out:
# [15.249754830964884,
#  7.639033595657207,
#  5.591521053623555,
#  20.436575312849207,
#  14.196408960913113,
#  10.631216865912743,
#  20.70500570433272,
#  14.804199383130614,
#  4.093362673850133,
#  19.99131746364133,
#  20.605921381128397,
#  8.541138212453207,
#  18.770241179086288,
#  20.67042457686711,
#  14.825729332543656,
#  9.939652860927614,
#  16.843006933765608,
#  18.37436999552864,
#  17.196772385830496,
#  9.135467384845816,
#  13.224963371895344,
#  19.77841082323589,
#  15.425237890029948,
#  12.366860839357772,
#  11.372489137825177,
#  18.32172188113932,
#  6.987319799950741,
#  9.553016797007302,
#  8.495037198611126,
#  17.75783466208105,
#  20.70798683307637,
#  20.980834990574653,
#  8.646585051444456,
#  11.476531415482588,
#  9.607159743159515,
#  6.400755674139312,
#  19.70373599566192,
#  21.773437124991414,
#  5.551698801630956,
#  10.91545452386518,
#  21.421996970826196,
#  20.477042442961448,
#  5.983227875875873,
#  22.147278390247887,
# ...

# %%
len(L)
# Out:
# 500
